# %%
import pandas as pd

# %%
# Specying path to file
# Mac:
stats = pd.read_csv('/Users/nikmeruva/Desktop/Python Data Analysis Course/P4-Demographic-Data.csv')

# %%
print(stats)
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
len(stats)  #Num of Rows
# Out:
# 195

# %%
stats.columns #Seeing of Columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
len(stats.columns) # num of column
# Out:
# 5

# %%
stats.head(6) # Prints top rows
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
stats.tail(6) # Prints bottom rows
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.info() # Info on columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
print(stats.describe()) # Stats on columns
print(stats.describe().transpose())
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
stats.columns = ['Country Name','Country Code','Birth Rate','Internet Users','Income Group']

print(stats.head())
stats.columns = ['a','b','c','d','e']
print(stats.head())
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
 stats[100:110]
# Out:
#                     a    b       c        d                    e
# 100             Libya  LBY  21.425  16.5000  Upper middle income
# 101         St. Lucia  LCA  15.430  46.2000  Upper middle income
# 102     Liechtenstein  LIE   9.200  93.8000          High income
# 103         Sri Lanka  LKA  17.863  21.9000  Lower middle income
# 104           Lesotho  LSO  28.738   5.0000  Lower middle income
# 105         Lithuania  LTU  10.100  68.4529          High income
# 106        Luxembourg  LUX  11.300  93.7765          High income
# 107            Latvia  LVA  10.200  75.2344          High income
# 108  Macao SAR, China  MAC  11.256  65.8000          High income
# 109           Morocco  MAR  21.023  56.0000  Lower middle income

# %%
stats[:10]
# Out:
#                       a    b       c        d                    e
# 0                 Aruba  ABW  10.244  78.9000          High income
# 1           Afghanistan  AFG  35.253   5.9000           Low income
# 2                Angola  AGO  45.985  19.1000  Upper middle income
# 3               Albania  ALB  12.877  57.2000  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0000          High income
# 5             Argentina  ARG  17.716  59.9000          High income
# 6               Armenia  ARM  13.308  41.9000  Lower middle income
# 7   Antigua and Barbuda  ATG  16.447  63.4000          High income
# 8             Australia  AUS  13.200  83.0000          High income
# 9               Austria  AUT   9.400  80.6188          High income

# %%
stats.columns = ['Country Name','Country Code','Birth Rate','Internet Users','Income Group']
stats[::-1] # Reverse
# Out:
#              Country Name Country Code  Birth Rate  Internet Users  \
# 194              Zimbabwe          ZWE      35.715            18.5
# 193                Zambia          ZMB      40.471            15.4
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 191          South Africa          ZAF      20.850            46.5
# 190           Yemen, Rep.          YEM      32.947            20.0
# ..                    ...          ...         ...             ...
# 4    United Arab Emirates          ARE      11.044            88.0
# 3                 Albania          ALB      12.877            57.2
# 2                  Angola          AGO      45.985            19.1
# 1             Afghanistan          AFG      35.253             5.9
# 0                   Aruba          ABW      10.244            78.9
#
#             Income Group
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ...

# %%
stats[::20] # Get every 20th row
# Out:
#     Country Name Country Code  Birth Rate  Internet Users         Income Group
# 0          Aruba          ABW      10.244         78.9000          High income
# 20       Belarus          BLR      12.500         54.1700  Upper middle income
# 40    Costa Rica          CRI      15.022         45.9600  Upper middle income
# 60         Gabon          GAB      30.555          9.2000  Upper middle income
# 80         India          IND      20.291         15.1000  Lower middle income
# 100        Libya          LBY      21.425         16.5000  Upper middle income
# 120   Mozambique          MOZ      39.705          5.4000           Low income
# 140       Poland          POL       9.600         62.8492          High income
# 160     Suriname          SUR      18.455         37.4000  Upper middle income
# 180      Uruguay          URY      14.374         57.6900          High income

# %%
print(stats['Country Name'].head())
['Country Name', 'BirthRate']
print()
print(stats[['Country Name','Birth Rate']].head())
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: Country Name, dtype: object
#
#            Country Name  Birth Rate
# 0                 Aruba      10.244
# 1           Afghanistan      35.253
# 2                Angola      45.985
# 3               Albania      12.877
# 4  United Arab Emirates      11.044

# %%
print(stats[4:8][['Country Name', 'Birth Rate']])
print(stats[['Country Name', 'Birth Rate']][4:8])
# Out:
#            Country Name  Birth Rate
# 4  United Arab Emirates      11.044
# 5             Argentina      17.716
# 6               Armenia      13.308
# 7   Antigua and Barbuda      16.447
#            Country Name  Birth Rate
# 4  United Arab Emirates      11.044
# 5             Argentina      17.716
# 6               Armenia      13.308
# 7   Antigua and Barbuda      16.447

# %%
res = stats["Birth Rate"]*stats["Internet Users"]
res.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Removing Col 
# stats.drop('Country Code', 1)

# %%
#Filtering Data Frames
# Filtering Rows
stats.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
filter = stats["Internet Users"] < 2
#print(filter[0:6])
print(stats[filter])  # Finding all true < 2
# Out:
#      Country Name Country Code  Birth Rate  Internet Users  \
# 11        Burundi          BDI      44.151             1.3
# 52        Eritrea          ERI      34.800             0.9
# 55       Ethiopia          ETH      32.925             1.9
# 64         Guinea          GIN      37.337             1.6
# 117       Myanmar          MMR      18.119             1.6
# 127         Niger          NER      49.661             1.7
# 154  Sierra Leone          SLE      36.729             1.7
# 156       Somalia          SOM      43.891             1.5
# 172   Timor-Leste          TLS      35.755             1.1
#
#             Income Group
# 11            Low income
# 52            Low income
# 55            Low income
# 64            Low income
# 117  Lower middle income
# 127           Low income
# 154           Low income
# 156           Low income
# 172  Lower middle income

# %%
filter2 = stats["Birth Rate"] > 40
stats[filter2]
# Out:
#          Country Name Country Code  Birth Rate  Internet Users  \
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 14       Burkina Faso          BFA      40.551             9.1
# 65        Gambia, The          GMB      42.525            14.0
# 115              Mali          MLI      44.138             3.5
# 127             Niger          NER      49.661             1.7
# 128           Nigeria          NGA      40.045            38.0
# 156           Somalia          SOM      43.891             1.5
# 167              Chad          TCD      45.745             2.3
# 178            Uganda          UGA      43.474            16.2
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
#
#             Income Group
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# ...

# %%
#stats[filter and filter2] # Error 
stats[filter & filter2]
# Out:
#     Country Name Country Code  Birth Rate  Internet Users Income Group
# 11       Burundi          BDI      44.151             1.3   Low income
# 127        Niger          NER      49.661             1.7   Low income
# 156      Somalia          SOM      43.891             1.5   Low income

# %%
stats[(stats["Birth Rate"] > 40) & (stats["Internet Users"] < 2)]
# Out:
#     Country Name Country Code  Birth Rate  Internet Users Income Group
# 11       Burundi          BDI      44.151             1.3   Low income
# 127        Niger          NER      49.661             1.7   Low income
# 156      Somalia          SOM      43.891             1.5   Low income

# %%
stats[stats["Income Group"] == "High income"]
# Out:
#               Country Name Country Code  Birth Rate  Internet Users  \
# 0                    Aruba          ABW      10.244           78.90
# 4     United Arab Emirates          ARE      11.044           88.00
# 5                Argentina          ARG      17.716           59.90
# 7      Antigua and Barbuda          ATG      16.447           63.40
# 8                Australia          AUS      13.200           83.00
# ..                     ...          ...         ...             ...
# 174    Trinidad and Tobago          TTO      14.590           63.80
# 180                Uruguay          URY      14.374           57.69
# 181          United States          USA      12.500           84.20
# 184          Venezuela, RB          VEN      19.842           54.90
# 185  Virgin Islands (U.S.)          VIR      10.700           45.30
#
#     Income Group
# 0    High income
# 4    High income
# 5    High income
# 7    High income
# 8    High income
# ..           ...
# 174  High income
# ...

# %%
# How to get the unique categories
stats["Income Group"].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats[stats["Country Name"] == "Malta"]
# Out:
#     Country Name Country Code  Birth Rate  Internet Users Income Group
# 116        Malta          MLT         9.5         68.9138  High income

# %%
#.at # for labels. Important: even ntegers are treated as labels
#.at #for integer location
print(stats.head())
print(stats.iat[3,4]) # 3rd row, 4th col
print(stats.iat[0,1])
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# Upper middle income
# ABW

# %%
stats.at[2, 'Birth Rate'] # second row and 'Birth Rate'
# Out:
# 45.985

# %%
#why we need .at
sub10 = stats[::10]
print(sub10)
print()
print(sub10.iat[10,0])               # Look at the difference
print(sub10.at[10, 'Country Name'])  # Look at the difference
# Out:
#     Country Name Country Code  Birth Rate  Internet Users         Income Group
# 0          Aruba          ABW      10.244       78.900000          High income
# 10    Azerbaijan          AZE      18.300       58.700000  Upper middle income
# 20       Belarus          BLR      12.500       54.170000  Upper middle income
# 30        Canada          CAN      10.900       85.800000          High income
# 40    Costa Rica          CRI      15.022       45.960000  Upper middle income
# 50       Ecuador          ECU      21.070       40.353684  Upper middle income
# 60         Gabon          GAB      30.555        9.200000  Upper middle income
# 70     Greenland          GRL      14.500       65.800000          High income
# 80         India          IND      20.291       15.100000  Lower middle income
# 90    Kazakhstan          KAZ      22.730       54.000000  Upper middle income
# 100        Libya          LBY      21.425       16.500000  Upper middle income
# ...

# %%
## Introduction to Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Distribution:
vis1 = sns.distplot(stats["Internet Users"])

# %%
vis1 = sns.distplot(stats["Internet Users"], bins=30)

# %%
vis2 = sns.boxplot(data=stats, x="Income Group", y="Birth Rate")

# %%
#Seasborn Gallery
vis3 = sns.lmplot(data=stats, x="Internet Users", y="Birth Rate", hue='Income Group', fit_reg=False, size=10, aspect=2)

# %%
#Keyword Arguments
vis3 = sns.lmplot(data=stats, x="Internet Users", y="Birth Rate", hue='Income Group', \
                  fit_reg=False, size=8, scatter_kws={"s":100})
